# %%
# use # to create comment

# %%
# click on Help and then click on keyboard shortcut (Or, simply press H) to know the use of 
# Shift+ENTER, 
# Alt+ENTER,and 
# Ctrl+ENTER 
# to avoid pressing the play/run button again and again
